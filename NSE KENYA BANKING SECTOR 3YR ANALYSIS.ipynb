# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
import pandas_datareader as pdr
import datetime as dt
import seaborn as sns

# %%
print("Before, figure default size is: ", plt.rcParams["figure.figsize"])
plt.rcParams["figure.figsize"] = (12, 12)
print("After, figure default size is: ", plt.rcParams["figure.figsize"])
# Out:
# Before, figure default size is:  [6.4, 4.8]
# After, figure default size is:  [12.0, 12.0]

# %%
data = pd.read_csv("NSE KENYA BANKING SECTOR 3YR HISTORICAL PRICES.csv", index_col=0, parse_dates=True)

# %%
data.head()
# Out:
#             ABSA BANK  CO-OP BANK  EQUITY BANK  KENCOMM BANK   NCBA  \
# Date
# 2021-12-31      11.85       12.95        52.75         45.45  25.20
# 2021-12-30      11.70       12.90        51.00         45.15  26.00
# 2021-12-29      11.80       12.90        50.00         45.00  25.30
# 2021-12-28      11.60       12.70        49.60         44.95  25.45
# 2021-12-24      11.55       12.45        48.50         45.20  25.75
#
#             STANCHART BANK
# Date
# 2021-12-31          128.25
# 2021-12-30          128.00
# 2021-12-29          128.00
# 2021-12-28          128.00
# 2021-12-24          128.00

# %%
data.tail()
# Out:
#             ABSA BANK  CO-OP BANK  EQUITY BANK  KENCOMM BANK   NCBA  \
# Date
# 2019-01-08      10.90       13.85        33.75         37.40  24.86
# 2019-01-07      10.90       13.85        33.60         37.35  24.91
# 2019-01-04      10.85       13.90        33.75         37.35  25.14
# 2019-01-03      10.85       13.80        34.10         37.05  25.14
# 2019-01-02      10.85       13.85        34.65         37.10  25.14
#
#             STANCHART BANK
# Date
# 2019-01-08          179.32
# 2019-01-07          179.32
# 2019-01-04          179.32
# 2019-01-03          179.32
# 2019-01-02          179.32

# %%
data = data.reindex(index=data.index[::-1])

# %%
data.head()
# Out:
#             ABSA BANK  CO-OP BANK  EQUITY BANK  KENCOMM BANK   NCBA  \
# Date
# 2019-01-02      10.85       13.85        34.65         37.10  25.14
# 2019-01-03      10.85       13.80        34.10         37.05  25.14
# 2019-01-04      10.85       13.90        33.75         37.35  25.14
# 2019-01-07      10.90       13.85        33.60         37.35  24.91
# 2019-01-08      10.90       13.85        33.75         37.40  24.86
#
#             STANCHART BANK
# Date
# 2019-01-02          179.32
# 2019-01-03          179.32
# 2019-01-04          179.32
# 2019-01-07          179.32
# 2019-01-08          179.32

# %%
data.tail()
# Out:
#             ABSA BANK  CO-OP BANK  EQUITY BANK  KENCOMM BANK   NCBA  \
# Date
# 2021-12-24      11.55       12.45        48.50         45.20  25.75
# 2021-12-28      11.60       12.70        49.60         44.95  25.45
# 2021-12-29      11.80       12.90        50.00         45.00  25.30
# 2021-12-30      11.70       12.90        51.00         45.15  26.00
# 2021-12-31      11.85       12.95        52.75         45.45  25.20
#
#             STANCHART BANK
# Date
# 2021-12-24          128.00
# 2021-12-28          128.00
# 2021-12-29          128.00
# 2021-12-30          128.00
# 2021-12-31          128.25

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.dtypes
# Out:
# ABSA BANK         float64
# CO-OP BANK        float64
# EQUITY BANK       float64
# KENCOMM BANK      float64
# NCBA              float64
# STANCHART BANK    float64
# dtype: object

# %%
data['ABSA BANK']
# Out:
# Date
# 2019-01-02    10.85
# 2019-01-03    10.85
# 2019-01-04    10.85
# 2019-01-07    10.90
# 2019-01-08    10.90
#               ...
# 2021-12-24    11.55
# 2021-12-28    11.60
# 2021-12-29    11.80
# 2021-12-30    11.70
# 2021-12-31    11.85
# Name: ABSA BANK, Length: 753, dtype: float64

# %%
data.plot()
# Out:
# <img src="data:image/png;base64,..." width="1200">
# <AxesSubplot:xlabel='Date'>

# %%
fig, ax = plt.subplots(3, 2)
data['ABSA BANK'].plot(ax=ax[0, 0], title="ABSA BANK")
data['CO-OP BANK'].plot(ax=ax[0, 1], title="CO-OP BANK")
data['EQUITY BANK'].plot(ax=ax[1, 0], title="EQUITY BANK")
data['KENCOMM BANK'].plot(ax=ax[1, 1], title="KENYA COMMERCIAL BANK")
data['NCBA'].plot(ax=ax[2, 0], title="NCBA")
data['STANCHART BANK'].plot(ax=ax[2, 1], title="STANDARD CHARTERED BANK")
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
data.insert(1, 'ABSA DAILY returns', data['ABSA BANK'].pct_change())
data.insert(3, 'CO-OP DAILY returns', data['CO-OP BANK'].pct_change())
data.insert(5, 'EQUITY DAILY returns', data['EQUITY BANK'].pct_change())
data.insert(7, 'KCB DAILY returns', data['KENCOMM BANK'].pct_change())
data.insert(9, 'NCBA DAILY returns', data['NCBA'].pct_change())
data.insert(11, 'SCB DAILY returns', data['STANCHART BANK'].pct_change())

# %%
data.head()
# Out:
#             ABSA BANK  ABSA DAILY returns  CO-OP BANK  CO-OP DAILY returns  \
# Date
# 2019-01-02      10.85                 NaN       13.85                  NaN
# 2019-01-03      10.85            0.000000       13.80            -0.003610
# 2019-01-04      10.85            0.000000       13.90             0.007246
# 2019-01-07      10.90            0.004608       13.85            -0.003597
# 2019-01-08      10.90            0.000000       13.85             0.000000
#
#             EQUITY BANK  EQUITY DAILY returns  KENCOMM BANK  \
# Date
# 2019-01-02        34.65                   NaN         37.10
# 2019-01-03        34.10             -0.015873         37.05
# 2019-01-04        33.75             -0.010264         37.35
# 2019-01-07        33.60             -0.004444         37.35
# 2019-01-08        33.75              0.004464         37.40
#
#             KCB DAILY returns   NCBA  NCBA DAILY returns  STANCHART BANK  \
# Date
# 2019-01-02                NaN  25.14                 NaN          179.32
# 2019-01-03          -0.001348  25.14            0.000000          179.32
# 2019-01-04           0.008097  25.14            0.000000          179.32
# 2019-01-07           0.000000  24.91           -0.009149          179.32
# 2019-01-08           0.001339  24.86           -0.002007          179.32
#
#             SCB DAILY returns
# Date
# 2019-01-02                NaN
# 2019-01-03                0.0
# 2019-01-04                0.0
# 2019-01-07                0.0
# 2019-01-08                0.0

# %%
data.corr(method='pearson')
# Out:
#                       ABSA BANK  ABSA DAILY returns  CO-OP BANK  \
# ABSA BANK              1.000000            0.068809    0.767098
# ABSA DAILY returns     0.068809            1.000000    0.021536
# CO-OP BANK             0.767098            0.021536    1.000000
# CO-OP DAILY returns    0.001088            0.153904    0.073130
# EQUITY BANK            0.575283            0.066848    0.636868
# EQUITY DAILY returns  -0.016640            0.235387    0.018543
# KENCOMM BANK           0.725300            0.059152    0.759951
# KCB DAILY returns     -0.020448            0.197015    0.016523
# NCBA                   0.794088            0.018442    0.789430
# NCBA DAILY returns    -0.002879            0.109068    0.046240
# STANCHART BANK         0.639856           -0.046657    0.367572
# SCB DAILY returns      0.043947            0.063313    0.052149
#
#                       CO-OP DAILY returns  EQUITY BANK  EQUITY DAILY returns  \
# ABSA BANK                        0.001088     0.575283             -0.016640
# ABSA DAILY returns               0.153904     0.066848              0.235387
# CO-OP BANK                       0.073130     0.636868              0.018543
# CO-OP DAILY returns              1.000000     0.028934              0.302679
# EQUITY BANK                      0.028934     1.000000              0.062930
# EQUITY DAILY returns             0.302679     0.062930              1.000000
# KENCOMM BANK                     0.041740     0.921804              0.042224
# KCB DAILY returns                0.347631     0.034246              0.610729
# NCBA                            -0.010908     0.442609              0.003938
# NCBA DAILY returns               0.188025     0.009882              0.214014
# STANCHART BANK                  -0.043101    -0.142623             -0.049694
# SCB DAILY returns               -0.014595     0.039982              0.028497
#
#                       KENCOMM BANK  KCB DAILY returns      NCBA  \
# ABSA BANK                 0.725300          -0.020448  0.794088
# ABSA DAILY returns        0.059152           0.197015  0.018442
# CO-OP BANK                0.759951           0.016523  0.789430
# CO-OP DAILY returns       0.041740           0.347631 -0.010908
# EQUITY BANK               0.921804           0.034246  0.442609
# EQUITY DAILY returns      0.042224           0.610729  0.003938
# KENCOMM BANK              1.000000           0.064080  0.630591
# KCB DAILY returns         0.064080           1.000000  0.009673
# NCBA                      0.630591           0.009673  1.000000
# NCBA DAILY returns        0.022375           0.271031  0.081566
# STANCHART BANK            0.112224          -0.035880  0.633061
# SCB DAILY returns         0.049070           0.065345  0.034034
#
#                       NCBA DAILY returns  STANCHART BANK  SCB DAILY returns
# ABSA BANK                      -0.002879        0.639856           0.043947
# ABSA DAILY returns              0.109068       -0.046657           0.063313
# CO-OP BANK                      0.046240        0.367572           0.052149
# CO-OP DAILY returns             0.188025       -0.043101          -0.014595
# EQUITY BANK                     0.009882       -0.142623           0.039982
# EQUITY DAILY returns            0.214014       -0.049694           0.028497
# KENCOMM BANK                    0.022375        0.112224           0.049070
# KCB DAILY returns               0.271031       -0.035880           0.065345
# NCBA                            0.081566        0.633061           0.034034
# NCBA DAILY returns              1.000000       -0.004051           0.041665
# STANCHART BANK                 -0.004051        1.000000           0.070823
# SCB DAILY returns               0.041665        0.070823           1.000000

# %%
data.insert(2, 'ABSA CR', np.exp(np.log1p(data['ABSA DAILY returns']).cumsum()))
data.insert(5, 'CO-OP CR', np.exp(np.log1p(data['CO-OP DAILY returns']).cumsum()))
data.insert(8, 'EQUITY CR', np.exp(np.log1p(data['EQUITY DAILY returns']).cumsum()))
data.insert(11, 'KCB CR', np.exp(np.log1p(data['KCB DAILY returns']).cumsum()))
data.insert(14, 'NCBA CR', np.exp(np.log1p(data['NCBA DAILY returns']).cumsum()))
data.insert(17, 'SCB CR', np.exp(np.log1p(data['SCB DAILY returns']).cumsum()))

# %%
data.head()
# Out:
#             ABSA BANK  ABSA DAILY returns   ABSA CR  CO-OP BANK  \
# Date
# 2019-01-02      10.85                 NaN       NaN       13.85
# 2019-01-03      10.85            0.000000  1.000000       13.80
# 2019-01-04      10.85            0.000000  1.000000       13.90
# 2019-01-07      10.90            0.004608  1.004608       13.85
# 2019-01-08      10.90            0.000000  1.004608       13.85
#
#             CO-OP DAILY returns  CO-OP CR  EQUITY BANK  EQUITY DAILY returns  \
# Date
# 2019-01-02                  NaN       NaN        34.65                   NaN
# 2019-01-03            -0.003610   0.99639        34.10             -0.015873
# 2019-01-04             0.007246   1.00361        33.75             -0.010264
# 2019-01-07            -0.003597   1.00000        33.60             -0.004444
# 2019-01-08             0.000000   1.00000        33.75              0.004464
#
#             EQUITY CR  KENCOMM BANK  KCB DAILY returns    KCB CR   NCBA  \
# Date
# 2019-01-02        NaN         37.10                NaN       NaN  25.14
# 2019-01-03   0.984127         37.05          -0.001348  0.998652  25.14
# 2019-01-04   0.974026         37.35           0.008097  1.006739  25.14
# 2019-01-07   0.969697         37.35           0.000000  1.006739  24.91
# 2019-01-08   0.974026         37.40           0.001339  1.008086  24.86
#
#             NCBA DAILY returns   NCBA CR  STANCHART BANK  SCB DAILY returns  \
# Date
# 2019-01-02                 NaN       NaN          179.32                NaN
# 2019-01-03            0.000000  1.000000          179.32                0.0
# 2019-01-04            0.000000  1.000000          179.32                0.0
# 2019-01-07           -0.009149  0.990851          179.32                0.0
# 2019-01-08           -0.002007  0.988862          179.32                0.0
#
#             SCB CR
# Date
# 2019-01-02     NaN
# 2019-01-03     1.0
# 2019-01-04     1.0
# 2019-01-07     1.0
# 2019-01-08     1.0

# %%
fig, ax = plt.subplots()
data[['ABSA CR', 'CO-OP CR', 'EQUITY CR', 'KCB CR', 'NCBA CR', 'SCB CR']].plot(ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="1200">
# <AxesSubplot:xlabel='Date'>
